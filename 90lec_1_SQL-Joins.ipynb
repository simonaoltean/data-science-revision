# %% [markdown]
# # SQL Joins
#
# We talked about joining tables together in Module 1. In this lecture, we are going to revisit this concept again.
# ![Joins](../assets/sql-joins.png)
#
#
# - LEFT JOIN returns all records from the left table and records from the right table that are found in the left table
# - RIGHT JOIN returns all records from the right table and records from the left table that are found in the right table (not supported in SQlite)
# - INNER JOIN only returns records that are present in both tables
# - FULL JOIN returns all records from both tables (not supported in SQlite)
#
#
# When joining tables together, it's important to understand different types of relationships.
#
# - One-to-one
# - One-to-many
# - Many-to-many
#
# Here is standard SQL syntax for joining tables together
#
# <code> SELECT a.col1, a.col2, b.col3, b.col4
#        FROM table1 a
#        _LEFT_/_RIGHT_/_INNER_/_FULL_ JOIN table2 b
#        ON a.col1 = b.col2 </code>
#
# More than two tables can be joined in SQL. Column names used to join tables don't need to be the same (unlike Pandas). You can also join on more than two columns
#
# <code> SELECT a.col1, a.col2, b.col3, b.col4
#        FROM table1 a
#        _LEFT_/_RIGHT_/_INNER_/_FULL_ JOIN table2 b
#        ON a.col1 = b.col2 and a.col3 = b.col3 </code>

# %%
import pandas as pd
import sqlite3

# %%
# create sqlite db
info = pd.read_csv("../data/customer-info.csv")
loyalty = pd.read_csv("../data/customer-loyalty.csv")
sales2019 = pd.read_csv("../data/sales2019.csv")
sales2020 = pd.read_csv("../data/sales2020.csv")
sales2021 = pd.read_csv("../data/sales2021.csv")
zipcode = pd.read_csv("../data/Zipcode-ZCTA-Population-Density-And-Area-Unsorted.csv")
conn = sqlite3.connect('../data/generalstore.sqlite') 
info.to_sql('info',con=conn,index=False,if_exists='replace')
loyalty.to_sql('loyalty',con=conn,index=False,if_exists='replace')
sales2019.to_sql('sales2019',con=conn,index=False,if_exists='replace')
sales2020.to_sql('sales2020',con=conn,index=False,if_exists='replace')
sales2021.to_sql('sales2021',con=conn,index=False,if_exists='replace')
zipcode.to_sql('zipcode',con=conn,index=False,if_exists='replace')
# Out:
# 33144

# %%
#Returns the table name. Including ones that we have used previously. 

pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'",con=conn)
# Out:
#         name
# 0  SALES_ALL
# 1     Output
# 2       info
# 3    loyalty
# 4  sales2019
# 5  sales2020
# 6  sales2021
# 7    zipcode

# %%
pd.read_sql("""SELECT *
                FROM info
                LIMIT 5""", conn)
# Out:
#    CustomerID              Name  CustomerSince  Age State  ZipCode Occupation
# 0        1001      Harry Potter           2020   20    NJ     7960    Teacher
# 1        1002  Hermione Granger           2021   20    NY    10025     Lawyer
# 2        1003      Draco Malfoy           2019   20    CT     6807    Manager
# 3        1004  Albus Dumbledore           2019   70    NJ     7030  Professor
# 4        1005     Severus Snape           2019   50    NJ     7960  Professor

# %%
pd.read_sql("""SELECT *
                FROM zipcode
                LIMIT 5""", conn) # not ideal naming convention
# Out:
#    Zip/ZCTA  2010 Population  Land-Sq-Mi  Density Per Sq Mile
# 0       601                0      64.348                  0.0
# 1       602                0      30.613                  0.0
# 2       603                0      31.616                  0.0
# 3       606                0      42.309                  0.0
# 4       610                0      35.916                  0.0

# %%
## Left join info with zip code
pd.read_sql("""
            SELECT t1.*, t2.*
            FROM info t1
            LEFT JOIN zipcode t2
            ON t1.ZipCode = t2.[Zip/ZCTA]
            """, conn)
# Out:
#     CustomerID                Name  CustomerSince  Age State  ZipCode  \
# 0         1001        Harry Potter           2020   20    NJ     7960
# 1         1002    Hermione Granger           2021   20    NY    10025
# 2         1003        Draco Malfoy           2019   20    CT     6807
# 3         1004    Albus Dumbledore           2019   70    NJ     7030
# 4         1005       Severus Snape           2019   50    NJ     7960
# 5         1006         Ron Weasley           2020   20    PA    19019
# 6         1007               Dobby           2021  150    NY    10014
# 7         1008  Minerva McGonagall           2019   68    NY    10013
# 8         1009  Neville Longbottom           2020   20    NJ     7035
# 9         1010       Luna Lovegood           2020   19    MA     2101
# 10        1011    Katniss Everdeen           2019   25    WA    98101
# 11        1012       Peeta Mellark           2019   25    WA    98101
# 12        1013      Gale Hawthorne           2021   26    CA    90210
# 13        1014  Haymitch Abernathy           2021   45    CA    90210
# 14        1015               Cinna           2020   38    CA    90291
# 15        1016                 Rue           2021   18    OR    97035
# 16        1017   Primrose Everdeen           2019   18    OR    97035
# 17        1018     Coriolanus Snow           2019   75    DC    20001
# 18        1019       Effie Trinket           2019   40    DC    20005
# 19        1020       Finnick Odair           2020   30    CA    90291
# 20        1021       Beetee Latier           2020   55    PA    15106
#
#              Occupation  Zip/ZCTA  2010 Population  Land-Sq-Mi  \
# 0               Teacher    7960.0          43747.0      35.019
# 1                Lawyer   10025.0          94600.0       0.752
# 2               Manager    6807.0           7150.0       3.145
# 3             Professor    7030.0          50005.0       1.264
# 4             Professor    7960.0          43747.0      35.019
# 5               Teacher       NaN              NaN         NaN
# 6             House Elf   10014.0          31959.0       0.550
# 7             Principal   10013.0          27700.0       0.550
# 8              Botanist    7035.0          10607.0       6.716
# 9       Cryptozoologist       NaN              NaN         NaN
# 10  Crossfit Instructor   98101.0          10238.0       0.519
# 11                Baker   98101.0          10238.0       0.519
# 12  Crossfit Instructor   90210.0          21741.0      10.126
# 13            Bartender   90210.0          21741.0      10.126
# 14             Designer   90291.0          28341.0       2.498
# 15             Botanist   97035.0          23912.0       6.032
# 16               Doctor   97035.0          23912.0       6.032
# 17           Politician   20001.0          38551.0       2.184
# 18             Designer   20005.0          12775.0       0.426
# 19  Crossfit Instructor   90291.0          28341.0       2.498
# 20            Professor   15106.0          18536.0      11.169
#
#     Density Per Sq Mile
# 0           1249.236129
# 1         125797.872300
# 2           2273.449921
# 3          39560.917720
# 4           1249.236129
# 5                   NaN
# 6          58107.272730
# 7          50363.636360
# 8           1579.362716
# 9                   NaN
# 10         19726.396920
# 11         19726.396920
# 12          2147.047205
# 13          2147.047205
# 14         11345.476380
# 15          3964.190981
# 16          3964.190981
# 17         17651.556780
# 18         29988.262910
# 19         11345.476380
# 20          1659.593518

# %%
## Inner join info with zip code
pd.read_sql("""
            SELECT t1.*, t2.*
            FROM info t1
            JOIN zipcode t2
            ON t1.ZipCode = t2.[Zip/ZCTA]
            """, conn)
# Out:
#     CustomerID                Name  CustomerSince  Age State  ZipCode  \
# 0         1001        Harry Potter           2020   20    NJ     7960
# 1         1002    Hermione Granger           2021   20    NY    10025
# 2         1003        Draco Malfoy           2019   20    CT     6807
# 3         1004    Albus Dumbledore           2019   70    NJ     7030
# 4         1005       Severus Snape           2019   50    NJ     7960
# 5         1007               Dobby           2021  150    NY    10014
# 6         1008  Minerva McGonagall           2019   68    NY    10013
# 7         1009  Neville Longbottom           2020   20    NJ     7035
# 8         1011    Katniss Everdeen           2019   25    WA    98101
# 9         1012       Peeta Mellark           2019   25    WA    98101
# 10        1013      Gale Hawthorne           2021   26    CA    90210
# 11        1014  Haymitch Abernathy           2021   45    CA    90210
# 12        1015               Cinna           2020   38    CA    90291
# 13        1016                 Rue           2021   18    OR    97035
# 14        1017   Primrose Everdeen           2019   18    OR    97035
# 15        1018     Coriolanus Snow           2019   75    DC    20001
# 16        1019       Effie Trinket           2019   40    DC    20005
# 17        1020       Finnick Odair           2020   30    CA    90291
# 18        1021       Beetee Latier           2020   55    PA    15106
#
#              Occupation  Zip/ZCTA  2010 Population  Land-Sq-Mi  \
# 0               Teacher      7960            43747      35.019
# 1                Lawyer     10025            94600       0.752
# 2               Manager      6807             7150       3.145
# 3             Professor      7030            50005       1.264
# 4             Professor      7960            43747      35.019
# 5             House Elf     10014            31959       0.550
# 6             Principal     10013            27700       0.550
# 7              Botanist      7035            10607       6.716
# 8   Crossfit Instructor     98101            10238       0.519
# 9                 Baker     98101            10238       0.519
# 10  Crossfit Instructor     90210            21741      10.126
# 11            Bartender     90210            21741      10.126
# 12             Designer     90291            28341       2.498
# 13             Botanist     97035            23912       6.032
# 14               Doctor     97035            23912       6.032
# 15           Politician     20001            38551       2.184
# 16             Designer     20005            12775       0.426
# 17  Crossfit Instructor     90291            28341       2.498
# 18            Professor     15106            18536      11.169
#
#     Density Per Sq Mile
# 0           1249.236129
# 1         125797.872300
# 2           2273.449921
# 3          39560.917720
# 4           1249.236129
# 5          58107.272730
# 6          50363.636360
# 7           1579.362716
# 8          19726.396920
# 9          19726.396920
# 10          2147.047205
# 11          2147.047205
# 12         11345.476380
# 13          3964.190981
# 14          3964.190981
# 15         17651.556780
# 16         29988.262910
# 17         11345.476380
# 18          1659.593518

# %%
# One to Many join
pd.read_sql("""
            SELECT * 
            FROM info t1
            LEFT JOIN Sales2019 t2
            ON t1.CustomerID = t2.CustomerID""", conn)
# Out:
#     CustomerID                Name  CustomerSince  Age State  ZipCode  \
# 0         1001        Harry Potter           2020   20    NJ     7960
# 1         1002    Hermione Granger           2021   20    NY    10025
# 2         1003        Draco Malfoy           2019   20    CT     6807
# 3         1003        Draco Malfoy           2019   20    CT     6807
# 4         1003        Draco Malfoy           2019   20    CT     6807
# 5         1004    Albus Dumbledore           2019   70    NJ     7030
# 6         1004    Albus Dumbledore           2019   70    NJ     7030
# 7         1005       Severus Snape           2019   50    NJ     7960
# 8         1006         Ron Weasley           2020   20    PA    19019
# 9         1007               Dobby           2021  150    NY    10014
# 10        1008  Minerva McGonagall           2019   68    NY    10013
# 11        1009  Neville Longbottom           2020   20    NJ     7035
# 12        1010       Luna Lovegood           2020   19    MA     2101
# 13        1011    Katniss Everdeen           2019   25    WA    98101
# 14        1011    Katniss Everdeen           2019   25    WA    98101
# 15        1011    Katniss Everdeen           2019   25    WA    98101
# 16        1012       Peeta Mellark           2019   25    WA    98101
# 17        1013      Gale Hawthorne           2021   26    CA    90210
# 18        1014  Haymitch Abernathy           2021   45    CA    90210
# 19        1015               Cinna           2020   38    CA    90291
# 20        1016                 Rue           2021   18    OR    97035
# 21        1017   Primrose Everdeen           2019   18    OR    97035
# 22        1018     Coriolanus Snow           2019   75    DC    20001
# 23        1019       Effie Trinket           2019   40    DC    20005
# 24        1020       Finnick Odair           2020   30    CA    90291
# 25        1021       Beetee Latier           2020   55    PA    15106
#
#              Occupation  CUSTOMERID  Sales2019   item_description        Date
# 0               Teacher         NaN        NaN               None        None
# 1                Lawyer         NaN        NaN               None        None
# 2               Manager      1003.0        5.0      Bed bug spray  11/15/2019
# 3               Manager      1003.0        5.0  Giant roach spray  12/15/2019
# 4               Manager      1003.0       10.0             Hammer  11/16/2019
# 5             Professor      1004.0       50.0          Chocolate  12/20/2019
# 6             Professor      1004.0       50.0          Chocolate  12/30/2019
# 7             Professor      1005.0       20.0            Potions  11/15/2019
# 8               Teacher         NaN        NaN               None        None
# 9             House Elf         NaN        NaN               None        None
# 10            Principal      1008.0       15.0              Books  11/17/2019
# 11             Botanist         NaN        NaN               None        None
# 12      Cryptozoologist         NaN        NaN               None        None
# 13  Crossfit Instructor      1011.0       20.0           Tote bag  12/30/2019
# 14  Crossfit Instructor      1011.0      150.0            Arrows   12/10/2019
# 15  Crossfit Instructor      1011.0      700.0                Bow   12/5/2019
# 16                Baker      1012.0      100.0              Flour   12/5/2019
# 17  Crossfit Instructor         NaN        NaN               None        None
# 18            Bartender         NaN        NaN               None        None
# 19             Designer         NaN        NaN               None        None
# 20             Botanist         NaN        NaN               None        None
# 21               Doctor      1017.0       20.0            Potions   12/5/2019
# 22           Politician      1018.0        5.0      Bed bug spray  11/20/2019
# 23             Designer      1019.0       50.0            Buttons   12/1/2019
# 24  Crossfit Instructor         NaN        NaN               None        None
# 25            Professor         NaN        NaN               None        None

# %%
#One to One join
pd.read_sql("""
            SELECT * 
            FROM info t1
            LEFT JOIN (
                    SELECT CUSTOMERID, sum(Sales2019) as Sales2019, count(item_description) as itemcnt
                    FROM Sales2019
                    GROUP BY CUSTOMERID) t2
            ON t1.CustomerID = t2.CustomerID""", conn)
# Out:
#     CustomerID                Name  CustomerSince  Age State  ZipCode  \
# 0         1001        Harry Potter           2020   20    NJ     7960
# 1         1002    Hermione Granger           2021   20    NY    10025
# 2         1003        Draco Malfoy           2019   20    CT     6807
# 3         1004    Albus Dumbledore           2019   70    NJ     7030
# 4         1005       Severus Snape           2019   50    NJ     7960
# 5         1006         Ron Weasley           2020   20    PA    19019
# 6         1007               Dobby           2021  150    NY    10014
# 7         1008  Minerva McGonagall           2019   68    NY    10013
# 8         1009  Neville Longbottom           2020   20    NJ     7035
# 9         1010       Luna Lovegood           2020   19    MA     2101
# 10        1011    Katniss Everdeen           2019   25    WA    98101
# 11        1012       Peeta Mellark           2019   25    WA    98101
# 12        1013      Gale Hawthorne           2021   26    CA    90210
# 13        1014  Haymitch Abernathy           2021   45    CA    90210
# 14        1015               Cinna           2020   38    CA    90291
# 15        1016                 Rue           2021   18    OR    97035
# 16        1017   Primrose Everdeen           2019   18    OR    97035
# 17        1018     Coriolanus Snow           2019   75    DC    20001
# 18        1019       Effie Trinket           2019   40    DC    20005
# 19        1020       Finnick Odair           2020   30    CA    90291
# 20        1021       Beetee Latier           2020   55    PA    15106
#
#              Occupation  CUSTOMERID  Sales2019  itemcnt
# 0               Teacher         NaN        NaN      NaN
# 1                Lawyer         NaN        NaN      NaN
# 2               Manager      1003.0       20.0      3.0
# 3             Professor      1004.0      100.0      2.0
# 4             Professor      1005.0       20.0      1.0
# 5               Teacher         NaN        NaN      NaN
# 6             House Elf         NaN        NaN      NaN
# 7             Principal      1008.0       15.0      1.0
# 8              Botanist         NaN        NaN      NaN
# 9       Cryptozoologist         NaN        NaN      NaN
# 10  Crossfit Instructor      1011.0      870.0      3.0
# 11                Baker      1012.0      100.0      1.0
# 12  Crossfit Instructor         NaN        NaN      NaN
# 13            Bartender         NaN        NaN      NaN
# 14             Designer         NaN        NaN      NaN
# 15             Botanist         NaN        NaN      NaN
# 16               Doctor      1017.0       20.0      1.0
# 17           Politician      1018.0        5.0      1.0
# 18             Designer      1019.0       50.0      1.0
# 19  Crossfit Instructor         NaN        NaN      NaN
# 20            Professor         NaN        NaN      NaN

# %%
# # # show customer id from 1001 through 1010 - Will fail
# pd.read_sql("""
#             SELECT * 
#             FROM info t1
#             LEFT JOIN (
#                     SELECT CUSTOMERID, SUM(Sales2019) AS Sales2019, COUNT(item_description) AS itemcnt
#                     FROM Sales2019
#                     GROUP BY CUSTOMERID) t2
#             ON t1.CustomerID = t2.CustomerID
#             WHERE CustomerID between 1001 and 1010""", conn) # ambiguous Column Name

# %%
# show customer id from 1001 through 1010
pd.read_sql("""
            SELECT * 
            FROM info t1
            LEFT JOIN (
                    SELECT CUSTOMERID, SUM(Sales2019) AS Sales2019, count(item_description) AS itemcnt
                    FROM Sales2019
                    GROUP BY CUSTOMERID) t2
            ON t1.CustomerID = t2.CustomerID
            WHERE t1.CustomerID between 1001 and 1010""", conn)
# Out:
#    CustomerID                Name  CustomerSince  Age State  ZipCode  \
# 0        1001        Harry Potter           2020   20    NJ     7960
# 1        1002    Hermione Granger           2021   20    NY    10025
# 2        1003        Draco Malfoy           2019   20    CT     6807
# 3        1004    Albus Dumbledore           2019   70    NJ     7030
# 4        1005       Severus Snape           2019   50    NJ     7960
# 5        1006         Ron Weasley           2020   20    PA    19019
# 6        1007               Dobby           2021  150    NY    10014
# 7        1008  Minerva McGonagall           2019   68    NY    10013
# 8        1009  Neville Longbottom           2020   20    NJ     7035
# 9        1010       Luna Lovegood           2020   19    MA     2101
#
#         Occupation  CUSTOMERID  Sales2019  itemcnt
# 0          Teacher         NaN        NaN      NaN
# 1           Lawyer         NaN        NaN      NaN
# 2          Manager      1003.0       20.0      3.0
# 3        Professor      1004.0      100.0      2.0
# 4        Professor      1005.0       20.0      1.0
# 5          Teacher         NaN        NaN      NaN
# 6        House Elf         NaN        NaN      NaN
# 7        Principal      1008.0       15.0      1.0
# 8         Botanist         NaN        NaN      NaN
# 9  Cryptozoologist         NaN        NaN      NaN

# %%
## ADDING WHERE, GROUP BY, and ORDER BY

# show 2021 sales by Occupation outside of NY, sort by sales in desc order
pd.read_sql("""
            SELECT Occupation, sum(Sales2021) as Sales
            FROM info t1
            LEFT JOIN (
                    SELECT CUSTOMER_ID, SUM(Sales2021) AS Sales2021, COUNT(item_description) AS itemcnt
                    FROM Sales2021
                    GROUP BY CUSTOMER_ID) t2
            ON t1.CustomerID = t2.Customer_ID
            WHERE State <> 'NY'
            GROUP BY Occupation
            ORDER BY Sales desc""", conn)
# Out:
#              Occupation  Sales
# 0   Crossfit Instructor  36037
# 1             Professor  30593
# 2              Designer  22865
# 3              Botanist  21587
# 4               Teacher  19135
# 5             Bartender  12665
# 6       Cryptozoologist  10255
# 7                 Baker   9790
# 8                Doctor   9445
# 9            Politician   9339
# 10              Manager   8091

# %% [markdown]
# # UNION
#
# UNION can also combine two or more tables but unlike JOIN, it appends tables on top of each other. In order for UNION to work correctly, you need to specify the same number of columns appearing in the same order from each table. The columns should also be of similar data type.
#
# When can UNION be helpful? If you have similar data stored in different tables. Perhaps, data from one year is stored in one table whereas data from another year is stored in a different table, and you want to combine it in one table, that's when you would use the UNION operator.
#
# ## UNION vs UNION ALL
#
# UNION: keeps unique records
# UNION ALL: keeps all records

# %%
# #One to One join - will fail
# pd.read_sql("""
#             SELECT * FROM Sales2019
#             UNION
#             SELECT * from Sales2020""", conn)

# %%
pd.read_sql("""

            SELECT CUSTOMERID, Sales2019, item_description, Date FROM Sales2019
            UNION ALL
            SELECT customer_id, Sales2020, item_description, YearMonth FROM Sales2020""", conn)

## Union ALL and Union -> same number of records but sorted differently
# Out:
#      CUSTOMERID  Sales2019   item_description        Date
# 0          1003          5      Bed bug spray  11/15/2019
# 1          1003         10             Hammer  11/16/2019
# 2          1003          5  Giant roach spray  12/15/2019
# 3          1004         50          Chocolate  12/20/2019
# 4          1004         50          Chocolate  12/30/2019
# ..          ...        ...                ...         ...
# 218        1017        301              Tools      202011
# 219        1018        541              Tools      202010
# 220        1019        340              Books      202001
# 221        1020        440            Grocery      202002
# 222        1021         24              Books      202010
#
# [223 rows x 4 columns]

# %%
pd.read_sql("""

            SELECT CUSTOMERID, Sales2019, item_description, Date FROM Sales2019
            UNION ALL
            SELECT customer_id, Sales2020, item_description, YearMonth FROM Sales2020
            UNION ALL
            SELECT customer_id, Sales2021, item_description, YearMonth FROM Sales2021""", conn)
# Out:
#      CUSTOMERID  Sales2019   item_description        Date
# 0          1003          5      Bed bug spray  11/15/2019
# 1          1003         10             Hammer  11/16/2019
# 2          1003          5  Giant roach spray  12/15/2019
# 3          1004         50          Chocolate  12/20/2019
# 4          1004         50          Chocolate  12/30/2019
# ..          ...        ...                ...         ...
# 648        1002        700            Grocery      202102
# 649        1007        365  Cleaning Supplies      202106
# 650        1013        528              Tools      202111
# 651        1014        484              Tools      202109
# 652        1016        514            Weapons      202106
#
# [653 rows x 4 columns]

# %%
## Clean output

pd.read_sql("""

            SELECT CUSTOMERID AS customer_id, 
                    Sales2019 AS Sales, 
                    item_description, 
                    substr(Date,7,4)||substr(Date,1,2) AS YearMonth
            FROM Sales2019
                UNION ALL
            SELECT customer_id, 
                    Sales2020 AS Sales, 
                    item_description, 
                    YearMonth 
            FROM Sales2020
                UNION ALL
            SELECT customer_id, 
                    Sales2021 AS Sales, 
                    item_description, 
                    YearMonth 
            FROM Sales2021
            ORDER BY customer_id, YearMonth""", conn)
# Out:
#      customer_id  Sales   item_description YearMonth
# 0           1001    417              Tools    202001
# 1           1001    234    Sewing Supplies    202002
# 2           1001    118       Pest Control    202005
# 3           1001    470            Produce    202005
# 4           1001    825           Tote bag    202005
# ..           ...    ...                ...       ...
# 648         1021    476            Grocery    202111
# 649         1021    193              Tools    202111
# 650         1021    560  Cleaning Supplies    202111
# 651         1021    358            Grocery    202112
# 652         1021    257            Grocery    202112
#
# [653 rows x 4 columns]

# %% [markdown]
# # Fuzzy Matching
#
# Sometimes you may have two tables that need to be joined on a string instead of an ID. This can be very painful!
#
# Certain variations of SQL have built-in functions that allow you to check how similar two strings are, for example, COMPGED calculates the Levenshtein distance (more on this in NLP) or the SOUNDEX function. Fuzzy matching isn't supported in SQLite
#
# [Fuzzywuzzy](https://pypi.org/project/fuzzywuzzy/) is a great Python alternative for fuzzy matching.
#
# There are also NoSQL databases that are great for entity resolution ([Elastic Search](https://www.elastic.co/elastic-stack/)).
