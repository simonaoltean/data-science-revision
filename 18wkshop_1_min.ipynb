# %% [markdown]
# # Introduction to Numpy and Pandas
#
# ## Warmup
#
# Run the following lines in the cell below:
#
# ```
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import seaborn as sn
# ```

# %%
# imports
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %% [markdown]
# 🛑 For the following question, you cannot use loops (`for`, `while`). _You shouldn't be using loops with pandas. It's time to break the habit... **before it becomes one!**_
#
# ## Exercise 1: DataFrame basics
#
# Consider the following Python dictionary `data` and Python list `labels` (This is just some meaningless data I made up with the theme of animals and trips to a vet):

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# 1.1 Create a DataFrame df from this dictionary data which has the index labels.

df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
# 1.2 Select only the rows where visits are 3 or more. Which types of animals are these?
df.loc[df.visits >= 3]

# Answer: They are two cats and a dog.
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no

# %%
# 1.3 Select the rows where visits are 3 and the animal is a cat

df.loc[(df.visits == 3) & (df.animal == 'cat')]
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# f    cat  2.0       3       no

# %%
# 1.4 Calculate the sum of all visits in df (i.e. the total number of visits).

df['visits'].sum()
# Out:
# 19

# %%
# 1.5 Calculate the mean age for each different animal in df.

df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.5
# dog      5.0
# snake    2.5
# Name: age, dtype: float64

# %%
# 1.6 Append a new row 'k' to df with your choice of values for each column. 
#Then delete that row to return the original DataFrame.
k = pd.Series({'animal':'parrot','age':'3','visits':2,'priority':'no'}, name='k')
df = df.append(k)
df
# Out:
# C:\Users\Simona\AppData\Local\Temp\ipykernel_16892\1604666102.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(k)
#    animal  age  visits priority
# a     cat  2.5       1      yes
# b     cat  3.0       3      yes
# c   snake  0.5       2       no
# d     dog  NaN       3      yes
# e     dog  5.0       2       no
# f     cat  2.0       3       no
# g   snake  4.5       1       no
# h     cat  NaN       1      yes
# i     dog  7.0       2       no
# j     dog  3.0       1       no
# k  parrot    3       2       no

# %%
#Then delete that row to return the original DataFrame.
df = df.drop('k')
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# ## Exercise 2: Iris Dataset Activity
#
# For this exercise, you will need to load dataset from the `Iris_Data.csv` file located in `data/`.
#
# _Hint: Use pandas "read" method._

# %%
# 2.1
# Load the data and assign it to a variable df
# print it out to verify that it is loaded. - pd.read_csv()
df = pd.read_csv("C:/Users/Simona/Desktop/Data Analysis/concordia-bootcamp/ds-intro-P3-modules-main/ds-intro-P3-modules-main/data/Iris_Data.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 2.2
#
# Create 4 box plots comparing sepal length, sepal width, petal length and petal width of the different species of iris.
#
# _HINT: To create boxplots you can you the code below. Make the appropriate changes to the column value, the Title and the ylabel of your graph._
#
# ```
# df.boxplot(column = "Column_To_Graph", by = 'species')
# plt.suptitle('')
# plt.title("_____ by Species")
# plt.ylabel("________")
# plt.show()
# ```

# %%
# 2.2 boxplot 1

df.boxplot(column = "sepal_length", by = 'species')
plt.suptitle('')
plt.title("Sepal Length by Species")
plt.ylabel("Sepal Length")
plt.show()

# %%
# 2.2 boxplot 2

df.boxplot(column = "sepal_width", by = 'species')
plt.suptitle('')
plt.title("Sepal Width by Species")
plt.ylabel("Sepal Width")
plt.show()

# %%
# 2.2 boxplot 3

df.boxplot(column = "petal_length", by = 'species')
plt.suptitle('')
plt.title("Petal Length by Species")
plt.ylabel("Petal Length")
plt.show()

# %%
# 2.2 boxplot 4

df.boxplot(column = "petal_width", by = 'species')
plt.suptitle('')
plt.title("Petal Width by Species")
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# ### 2.3
#
# In the following text cell, write which species had outliers in their boxplot (above) and for what variable.

# %% [markdown]
# The species 'Virginica' had outliers for the sepal length variable and the sepal width variable. The species 'Setosa' had outliers for the variables petal length and petal width. The species 'Versicolor' had outliers for the variable petal length.

# %% [markdown]
# Run the cell below. The output should be a scatter plot of sepal lengths of each iris species. The Sepal length entries for the Setosa species however will be red.

# %%
fig, ax = plt.subplots()
colors = {'setosa':'red', 'versicolor':'blue', 'virginica':'blue'}
ax.scatter(np.linspace(0,len(df['sepal_length']),len(df['sepal_length'])),df['sepal_length'], c=df['species'].apply(lambda x: colors[x]))
ax.set_xticks([])
plt.ylabel("Sepal Length")
plt.legend(df['species'])
plt.show()

# %% [markdown]
# ## Exercise 3: Covid-19 Reporting
#
# Run the cell below. We will be working with data on weekly reported Covid-19 cases in Toronto.

# %%
covid = pd.read_csv("C:/Users/Simona/Desktop/Data Analysis/concordia-bootcamp/ds-intro-P3-modules-main/ds-intro-P3-modules-main/data/COVID19_cases.csv/COVID19_cases.csv")
covid.head()
# Out:
#         Age Group  Assigned_ID Classification Client Gender  \
# 0  20 to 29 Years       276483      CONFIRMED        FEMALE
# 1  20 to 29 Years       276484      CONFIRMED        FEMALE
# 2  50 to 59 Years       276485      CONFIRMED        FEMALE
# 3  70 to 79 Years       276486      CONFIRMED        FEMALE
# 4  30 to 39 Years       276487      CONFIRMED        FEMALE
#
#   Currently Hospitalized Currently Intubated Currently in ICU  \
# 0                     No                  No               No
# 1                     No                  No               No
# 2                     No                  No               No
# 3                     No                  No               No
# 4                     No                  No               No
#
#           Episode Date Ever Hospitalized Ever Intubated Ever in ICU  FSA  \
# 0  2022-01-18T00:00:00                No             No          No  M1E
# 1  2022-01-20T00:00:00                No             No          No  M1G
# 2  2022-01-21T00:00:00                No             No          No  M1G
# 3  2022-01-21T00:00:00                No             No          No  M4S
# 4  2022-01-21T00:00:00                No             No          No  NaN
#
#     Neighbourhood Name  Outbreak Associated   Outcome        Reported Date  \
# 0            Guildwood             Sporadic  RESOLVED  2022-01-22T00:00:00
# 1          Morningside             Sporadic  RESOLVED  2022-01-22T00:00:00
# 2               Woburn             Sporadic  RESOLVED  2022-01-22T00:00:00
# 3  Mount Pleasant West             Sporadic  RESOLVED  2022-01-22T00:00:00
# 4                  NaN  Outbreak Associated  RESOLVED  2022-01-22T00:00:00
#
#                   Source of Infection     _id
# 0                      No Information  269053
# 1                      No Information  269054
# 2                      No Information  269055
# 3                      No Information  269056
# 4  Outbreaks, Healthcare Institutions  269057

# %%
# Call the 'Neighbourhood Name' column

covid['Neighbourhood Name']
# Out:
# 0                   Guildwood
# 1                 Morningside
# 2                      Woburn
# 3         Mount Pleasant West
# 4                         NaN
#                  ...
# 292380                Bendale
# 292381            Dorset Park
# 292382              West Hill
# 292383        Agincourt North
# 292384     Caledonia-Fairbank
# Name: Neighbourhood Name, Length: 292385, dtype: object

# %%
# Call every second row in the data frame.
covid[::2]
# Out:
#              Age Group  Assigned_ID Classification Client Gender  \
# 0       20 to 29 Years       276483      CONFIRMED        FEMALE
# 2       50 to 59 Years       276485      CONFIRMED        FEMALE
# 4       30 to 39 Years       276487      CONFIRMED        FEMALE
# 6       30 to 39 Years       276489      CONFIRMED          MALE
# 8       30 to 39 Years       276491      CONFIRMED        FEMALE
# ...                ...          ...            ...           ...
# 292376  20 to 29 Years       252898      CONFIRMED          MALE
# 292378  60 to 69 Years       252900      CONFIRMED        FEMALE
# 292380  40 to 49 Years       252902      CONFIRMED          MALE
# 292382  19 and younger       252904      CONFIRMED          MALE
# 292384  40 to 49 Years       252907      CONFIRMED        FEMALE
#
#        Currently Hospitalized Currently Intubated Currently in ICU  \
# 0                          No                  No               No
# 2                          No                  No               No
# 4                          No                  No               No
# 6                          No                  No               No
# 8                          No                  No               No
# ...                       ...                 ...              ...
# 292376                     No                  No               No
# 292378                     No                  No               No
# 292380                     No                  No               No
# 292382                     No                  No               No
# 292384                     No                  No               No
#
#                Episode Date Ever Hospitalized Ever Intubated Ever in ICU  FSA  \
# 0       2022-01-18T00:00:00                No             No          No  M1E
# 2       2022-01-21T00:00:00                No             No          No  M1G
# 4       2022-01-21T00:00:00                No             No          No  NaN
# 6       2022-01-18T00:00:00                No             No          No  M4C
# 8       2022-01-21T00:00:00                No             No          No  M3C
# ...                     ...               ...            ...         ...  ...
# 292376  2022-01-08T00:00:00                No             No          No  NaN
# 292378  2022-01-07T00:00:00               Yes            Yes         Yes  M1E
# 292380  2022-01-06T00:00:00                No             No          No  M1J
# 292382  2022-01-08T00:00:00                No             No          No  M1E
# 292384  2022-01-08T00:00:00                No             No          No  M6E
#
#         Neighbourhood Name  Outbreak Associated   Outcome  \
# 0                Guildwood             Sporadic  RESOLVED
# 2                   Woburn             Sporadic  RESOLVED
# 4                      NaN  Outbreak Associated  RESOLVED
# 6            Taylor-Massey             Sporadic  RESOLVED
# 8                      NaN             Sporadic  RESOLVED
# ...                    ...                  ...       ...
# 292376                 NaN             Sporadic  RESOLVED
# 292378           Guildwood             Sporadic  RESOLVED
# 292380             Bendale             Sporadic  RESOLVED
# 292382           West Hill             Sporadic  RESOLVED
# 292384  Caledonia-Fairbank  Outbreak Associated  RESOLVED
#
#               Reported Date                 Source of Infection     _id
# 0       2022-01-22T00:00:00                      No Information  269053
# 2       2022-01-22T00:00:00                      No Information  269055
# 4       2022-01-22T00:00:00  Outbreaks, Healthcare Institutions  269057
# 6       2022-01-22T00:00:00                      No Information  269059
# 8       2022-01-22T00:00:00                      No Information  269061
# ...                     ...                                 ...     ...
# 292376  2022-01-08T00:00:00                      No Information  245900
# 292378  2022-01-08T00:00:00                      No Information  245902
# 292380  2022-01-08T00:00:00                      No Information  245904
# 292382  2022-01-08T00:00:00                      No Information  245906
# 292384  2022-01-08T00:00:00  Outbreaks, Healthcare Institutions  245908
#
# [146193 rows x 18 columns]

# %%
# Call every third entry in the "Source of Infection" column.
covid['Source of Infection'][::3]
# Out:
# 0                             No Information
# 3                             No Information
# 6                             No Information
# 9                             No Information
# 12                            No Information
#                          ...
# 292371                        No Information
# 292374    Outbreaks, Healthcare Institutions
# 292377                        No Information
# 292380                        No Information
# 292383                        No Information
# Name: Source of Infection, Length: 97462, dtype: object

# %% [markdown]
# Call all rows in the dataframe where the infected patient was female. Then call all rows in the dataframe where the patient was male, ever hospitalized and in their 60s.

# %%
# Call all rows in the dataframe where the infected patient was female.
covid.loc[covid['Client Gender']=='FEMALE']
# Out:
#              Age Group  Assigned_ID Classification Client Gender  \
# 0       20 to 29 Years       276483      CONFIRMED        FEMALE
# 1       20 to 29 Years       276484      CONFIRMED        FEMALE
# 2       50 to 59 Years       276485      CONFIRMED        FEMALE
# 3       70 to 79 Years       276486      CONFIRMED        FEMALE
# 4       30 to 39 Years       276487      CONFIRMED        FEMALE
# ...                ...          ...            ...           ...
# 292375  60 to 69 Years       252897      CONFIRMED        FEMALE
# 292377  40 to 49 Years       252899      CONFIRMED        FEMALE
# 292378  60 to 69 Years       252900      CONFIRMED        FEMALE
# 292381    90 and older       252903      CONFIRMED        FEMALE
# 292384  40 to 49 Years       252907      CONFIRMED        FEMALE
#
#        Currently Hospitalized Currently Intubated Currently in ICU  \
# 0                          No                  No               No
# 1                          No                  No               No
# 2                          No                  No               No
# 3                          No                  No               No
# 4                          No                  No               No
# ...                       ...                 ...              ...
# 292375                     No                  No               No
# 292377                     No                  No               No
# 292378                     No                  No               No
# 292381                     No                  No               No
# 292384                     No                  No               No
#
#                Episode Date Ever Hospitalized Ever Intubated Ever in ICU  FSA  \
# 0       2022-01-18T00:00:00                No             No          No  M1E
# 1       2022-01-20T00:00:00                No             No          No  M1G
# 2       2022-01-21T00:00:00                No             No          No  M1G
# 3       2022-01-21T00:00:00                No             No          No  M4S
# 4       2022-01-21T00:00:00                No             No          No  NaN
# ...                     ...               ...            ...         ...  ...
# 292375  2021-12-28T00:00:00                No             No          No  M1V
# 292377  2022-01-08T00:00:00                No             No          No  M4H
# 292378  2022-01-07T00:00:00               Yes            Yes         Yes  M1E
# 292381  2022-01-05T00:00:00                No             No          No  M1P
# 292384  2022-01-08T00:00:00                No             No          No  M6E
#
#          Neighbourhood Name  Outbreak Associated   Outcome  \
# 0                 Guildwood             Sporadic  RESOLVED
# 1               Morningside             Sporadic  RESOLVED
# 2                    Woburn             Sporadic  RESOLVED
# 3       Mount Pleasant West             Sporadic  RESOLVED
# 4                       NaN  Outbreak Associated  RESOLVED
# ...                     ...                  ...       ...
# 292375              Steeles             Sporadic  RESOLVED
# 292377     Thorncliffe Park             Sporadic  RESOLVED
# 292378            Guildwood             Sporadic  RESOLVED
# 292381          Dorset Park  Outbreak Associated  RESOLVED
# 292384   Caledonia-Fairbank  Outbreak Associated  RESOLVED
#
#               Reported Date                 Source of Infection     _id
# 0       2022-01-22T00:00:00                      No Information  269053
# 1       2022-01-22T00:00:00                      No Information  269054
# 2       2022-01-22T00:00:00                      No Information  269055
# 3       2022-01-22T00:00:00                      No Information  269056
# 4       2022-01-22T00:00:00  Outbreaks, Healthcare Institutions  269057
# ...                     ...                                 ...     ...
# 292375  2022-01-08T00:00:00                      No Information  245899
# 292377  2022-01-08T00:00:00                      No Information  245901
# 292378  2022-01-08T00:00:00                      No Information  245902
# 292381  2022-01-08T00:00:00  Outbreaks, Healthcare Institutions  245905
# 292384  2022-01-08T00:00:00  Outbreaks, Healthcare Institutions  245908
#
# [153606 rows x 18 columns]

# %%
# Call all rows in the dataframe where the patient was male, ever hospitalized and in their 60s.
covid.loc[(covid['Client Gender']=='MALE') & (covid['Ever Hospitalized']=='Yes') & (covid['Age Group']=='60 to 69 Years')]
# Out:
#              Age Group  Assigned_ID Classification Client Gender  \
# 283     60 to 69 Years       276763      CONFIRMED          MALE
# 494     60 to 69 Years       276977      CONFIRMED          MALE
# 784     60 to 69 Years       277277      CONFIRMED          MALE
# 850     60 to 69 Years       277346      CONFIRMED          MALE
# 1007    60 to 69 Years       277501      CONFIRMED          MALE
# ...                ...          ...            ...           ...
# 289695  60 to 69 Years       250171      CONFIRMED          MALE
# 290161  60 to 69 Years       250642      CONFIRMED          MALE
# 290879  60 to 69 Years       251371      CONFIRMED          MALE
# 291324  60 to 69 Years       251819      CONFIRMED          MALE
# 292296  60 to 69 Years       252815      CONFIRMED          MALE
#
#        Currently Hospitalized Currently Intubated Currently in ICU  \
# 283                        No                  No               No
# 494                        No                  No               No
# 784                        No                  No               No
# 850                        No                  No               No
# 1007                       No                  No               No
# ...                       ...                 ...              ...
# 289695                     No                  No               No
# 290161                     No                  No               No
# 290879                     No                  No               No
# 291324                     No                  No               No
# 292296                     No                  No               No
#
#                Episode Date Ever Hospitalized Ever Intubated Ever in ICU  FSA  \
# 283     2022-01-21T00:00:00               Yes            Yes         Yes  M1B
# 494     2022-01-22T00:00:00               Yes            Yes         Yes  M1S
# 784     2022-01-22T00:00:00               Yes             No          No  M4P
# 850     2022-01-22T00:00:00               Yes            Yes         Yes  M2R
# 1007    2022-01-22T00:00:00               Yes            Yes         Yes  M9A
# ...                     ...               ...            ...         ...  ...
# 289695  2022-01-07T00:00:00               Yes             No          No  M1S
# 290161  2022-01-07T00:00:00               Yes             No          No  M1G
# 290879  2022-01-07T00:00:00               Yes             No          No  M8W
# 291324  2022-01-07T00:00:00               Yes             No          No  M6P
# 292296  2022-01-01T00:00:00               Yes            Yes         Yes  M1J
#
#                          Neighbourhood Name Outbreak Associated   Outcome  \
# 283                                 Malvern            Sporadic     FATAL
# 494            Agincourt South-Malvern West            Sporadic  RESOLVED
# 784                     Mount Pleasant West            Sporadic  RESOLVED
# 850                     Westminster-Branson            Sporadic  RESOLVED
# 1007             Islington-City Centre West            Sporadic     FATAL
# ...                                     ...                 ...       ...
# 289695         Agincourt South-Malvern West            Sporadic  RESOLVED
# 290161                               Woburn            Sporadic  RESOLVED
# 290879                          Long Branch            Sporadic  RESOLVED
# 291324  Dovercourt-Wallace Emerson-Junction            Sporadic  RESOLVED
# 292296                  Scarborough Village            Sporadic     FATAL
#
#               Reported Date Source of Infection     _id
# 283     2022-01-22T00:00:00      No Information  269332
# 494     2022-01-22T00:00:00      No Information  269541
# 784     2022-01-22T00:00:00      No Information  269831
# 850     2022-01-23T00:00:00      No Information  269897
# 1007    2022-01-23T00:00:00      No Information  270051
# ...                     ...                 ...     ...
# 289695  2022-01-07T00:00:00      No Information  243216
# 290161  2022-01-07T00:00:00      No Information  243682
# 290879  2022-01-08T00:00:00      No Information  244400
# 291324  2022-01-08T00:00:00      No Information  244845
# 292296  2022-01-08T00:00:00      No Information  245818
#
# [1362 rows x 18 columns]

# %% [markdown]
# Create 2 new columns in the dataframe, called 'Year' and 'Month' with the year and month values from the reported date columns respectively.
#
# **HINT**
# Your code should look like this.
#
# ```
# Dates = pd.to_datetime(covid['Episode Date'])
# covid['Dates'] = Dates
# ________ = covid['Dates'].dt.month
# ________ = covid['Dates'].dt.year
# ```

# %%
Dates = pd.to_datetime(covid['Episode Date'])
covid['Dates'] = Dates
Month = covid['Dates'].dt.month
Year = covid['Dates'].dt.year
covid['Month'] = Month
covid['Year'] = Year
covid.sample(5)
# Out:
#              Age Group  Assigned_ID Classification Client Gender  \
# 3488    30 to 39 Years       280025      CONFIRMED        FEMALE
# 292311  80 to 89 Years       252831      CONFIRMED          MALE
# 266619  40 to 49 Years       231328      CONFIRMED        FEMALE
# 234159  20 to 29 Years       235406      CONFIRMED        FEMALE
# 101802  19 and younger       277554      CONFIRMED          MALE
#
#        Currently Hospitalized Currently Intubated Currently in ICU  \
# 3488                       No                  No               No
# 292311                     No                  No               No
# 266619                     No                  No               No
# 234159                     No                  No               No
# 101802                     No                  No               No
#
#                Episode Date Ever Hospitalized Ever Intubated  ...  FSA  \
# 3488    2022-01-24T00:00:00                No             No  ...  M5H
# 292311  2022-01-08T00:00:00                No             No  ...  M1G
# 266619  2021-12-28T00:00:00                No             No  ...  M4G
# 234159  2021-12-31T00:00:00                No             No  ...  M6N
# 101802  2022-01-21T00:00:00                No             No  ...  M8X
#
#                        Neighbourhood Name Outbreak Associated   Outcome  \
# 3488                  Bay Street Corridor            Sporadic  RESOLVED
# 292311                        Morningside            Sporadic  RESOLVED
# 266619  Bridle Path-Sunnybrook-York Mills            Sporadic  RESOLVED
# 234159                       Mount Dennis            Sporadic  RESOLVED
# 101802                     Kingsway South            Sporadic  RESOLVED
#
#               Reported Date Source of Infection     _id      Dates Month  Year
# 3488    2022-01-26T00:00:00      No Information  272534 2022-01-24     1  2022
# 292311  2022-01-08T00:00:00      No Information  245833 2022-01-08     1  2022
# 266619  2021-12-31T00:00:00      No Information  224624 2021-12-28    12  2021
# 234159  2022-01-02T00:00:00      No Information  228669 2021-12-31    12  2021
# 101802  2022-01-23T00:00:00      No Information  270104 2022-01-21     1  2022
#
# [5 rows x 21 columns]

# %% [markdown]
# Now use the groupby function to group your entries in the data frame by Year and Month and print out the **total count** of cases per month. Make sure to save the number of cases per month as **Counts**.
#
# **HINT**  To get the counts of cases per month, you can use this code. Fill in the blanks.
#
#
# ```
# YearMonth = covid.groupby(['____', '____'])
# Counts = YearMonth['_id'].agg(['____'])
# print (Counts)
# ```

# %%
YearMonth = covid.groupby(['Year', 'Month'])
Counts = YearMonth['_id'].agg(['count'])
print (Counts)
# Out:
#             count
# Year Month
# 2020 1          4
#      2         26
#      3       3321
#      4       6544
#      5       2368
#      6        263
#      7         88
#      8          9
#      9         47
#      10       302
#      11     17033
#      12     39950
# 2021 1       6980
#      2         34
#      3        128
#      4      35970
#      5      26684
#      6        945
#      7          7
#      8          7
#      9         12
#      10         3
#      11        37
#      12     46698
# 2022 1      76470
#      2      22756
#      3       5699

# %% [markdown]
# Plot the "Counts" groupby object on a line graph by running the following line below:

# %%
Counts.plot()
plt.show()

# %% [markdown]
# 1. Create a new groupby object from the original data frame and group this data by "Client Gender".
# 2. Get a count of the number of patients in each Client Gender category and plot the result on a bar graph.
#
# **HINT** You can plot the bar graph using the following code.
#
# ```
# Counts.plot.bar()
# plt.ylabel('# of Covid Cases')
# plt.title('Covid Cases by Gender in Toronto')
# plt.show()
# ```

# %%
ClientGender = covid.groupby('Client Gender')
Gender_counts = ClientGender['_id'].agg(['count'])
print (Gender_counts)
# Out:
#                              count
# Client Gender
# FEMALE                      153606
# MALE                        136132
# NON-BINARY                      96
# NOT LISTED, PLEASE SPECIFY       3
# OTHER                           14
# TRANS MAN                       11
# TRANS WOMAN                     11
# TRANSGENDER                     11
# UNKNOWN                       2501

# %%
Gender_counts.plot.bar()
plt.ylabel('# of Covid Cases')
plt.title('Covid Cases by Gender in Toronto')
plt.show()
